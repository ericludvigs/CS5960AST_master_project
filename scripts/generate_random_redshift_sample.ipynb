# %%
import numpy as np

# %%
# randomly generate 8 integers between 0 and 33
rng = np.random.default_rng()
random_indices = rng.integers(0, 34, size=8)
print(sorted(random_indices.tolist()))
# Out:
# [1, 5, 6, 10, 20, 23, 24, 27]
